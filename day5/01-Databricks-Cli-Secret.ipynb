# %% [markdown]
# ### DataBricks CLI
#
# Launch Azure cloud shell.
#
# Select BASH option , BASH is Linux shell like cmd or ps in Windows. Please select BASH
#
# Mount Storage Account of yours, Select existing account of yours
#
# File share, click on Create file share , give a name like your-initial-file-share like combination
#
# File share useful to keep the downloaded files into azure shell on sub-sequent logins
#
# [You need to select cloud storage account]

# %% [markdown]
# ### DataBricks CLI
#
# Launch Azure cloud shell. [You need to select cloud storage account]
#
# ```
# virtualenv -p /usr/bin/python db-cli
# source db-cli/bin/activate
# pip install databricks-cli
# ```
#
#
# ensure command shows (db-cli) on left side of linux prompt

# %% [markdown]
# # tokens
#
# go to Settings, Developer, Token, Create token, copy the token paste when databricks cli prompt same.
#
# Select All Apis for API scope(s), you may select specific one for production and stronger security.. All Apis is not safe
#
#
# ```
# databricks configure --token
# ```
#
# Copy databricks host from address bar
#
# Databricks Host (should begin with https://): https://adb-xyz.azuredatabricks.net/
# Token:

# %% [markdown]
# #### Databricks Secret
#
# A scope is like a dict, contains key/value combination, while key is transparant, value contain secrets.

# %% [markdown]
# ``
# databricks secrets create-scope --scope sqlserver-creds
#
# databricks secrets put --scope sqlserver-creds --key username
#
# databricks secrets put --scope sqlserver-creds --key password

# %% [markdown]
# vi editor, key tips
#
# after file opened
#
# i - for insert/edit
#
# to save file
#
# ESC key then type    :wq        then press ENTER key
